# %% [markdown]
# # Adversarial Domain Adaptation
# ## first experiment
# adversarial adaptation instead of GPA on same features

# %%
from log_analysis import *

sb.set_context('talk')
sb.set_style('whitegrid')
sb.set_palette(kit())
logs = [
[
    'GPA/tuning/coco_piropo_100a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_fclayer_gTrue_seed_norot.log',
    'adversarial 1:1'
],
[
    'GPA/tuning/coco_piropo_100a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_fclayer_gTrue_seed_norot_ann.log',
    'adversarial 1:1, increasing λ'
],
# [
#     'GPA/tuning/coco_piropo_100a_TwoStageDetectorAdaptiveAdversarial_01_01_01_01_fclayer_gTrue_seed_norot.log',
#     'adversarial 0.1:0.1'
# ]
]

df, maxs = df_from_log(['setting'], ['bbox_mAP', 'bbox_mAP_75', 'bbox_mAP_50', 'LAMR'], logs, get_max=True)

g = sb.relplot(data=df[df['occurrence'] <= 40],
               x='occurrence',
               y='value',
               kind='line',
               hue='setting',
               col='metric',
               height=5,
               aspect=1.)
g.set_axis_labels('epoch', 'AP@50')
g.set_titles(col_template='{col_name}', row_template='')
print(maxs)
# Out:
# [{'bbox_mAP': (7.0, 0.583), 'bbox_mAP_75': (7.0, 0.665), 'bbox_mAP_50': (5.0, 0.901), 'LAMR': (6.0, 0.1321)}, {'bbox_mAP': (10.0, 0.579), 'bbox_mAP_75': (24.0, 0.674), 'bbox_mAP_50': (9.0, 0.91), 'LAMR': (27.0, 0.135)}]

# %% [markdown]
# ## experiment with λ settings
# Still on ROI/RCNN just as GPA

# %%
from log_analysis import *

sb.set_context('talk')
sb.set_style('whitegrid')
sb.set_palette(kit())
logs = [
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptive_0_0_0_0_fclayer_gTrue_seed_norot.log', 'fine-tune'],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptive_10_01_100_01_fclayer_gTrue_seed_norot.log',
    #     'GPA 10:0.1 | 100:0.1'
    # ],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_fclayer_gTrue_seed_direct1.log',
    #     'fc → adversarial, λ 1:1 increasing, lr × 100'
    # ],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_fclayer_gTrue_seed_direct2.log',
    #     'fc → adversarial, λ 1:1 increasing'
    # ],
    [
        'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct3.log',
        'adversarial, λ 1:1 increasing'
    ],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct4.log',
    #     'adversarial, λ 1:1 increasing, lr × 10'
    # ],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct5_adv.log',
    #     'adversarial pretraining'
    # ],
    [
        'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct10.log',
        'adversarial, λ 1:1 coupled'
    ],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct6.log',
    #     'adversarial, λ 1:1, pretrained'
    # ],
    [
        'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct5.log',
        'adversarial, λ 1:1 increasing, pretrained'
    ],
    [
        'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct7.log',
        'adversarial, λ 1:1 coupled, pretrained'
    ],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct8.log',
    #     'adversarial, λ 1:1 coupled, pretrained, , lr × 10'
    # ],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct9.log',
    #     'adversarial, λ 1:1 coupled, pretrained CTD'
    # ],
]

df, maxs = df_from_log(['setting'], ['bbox_mAP', 'bbox_mAP_75', 'bbox_mAP_50', 'LAMR'], logs, get_max=True)

g = sb.relplot(data=df[df['occurrence'] <= 40],
               x='occurrence',
               y='value',
               kind='line',
               hue='setting',
               col='metric',
               height=5,
               aspect=1.)
g.set_axis_labels('epoch', 'AP@50')
g.set_titles(col_template='{col_name}', row_template='')
print(maxs)
# g.savefig(f'images/tuning_gpa_adversarial.svg')
# Out:
# [{'bbox_mAP': (23.0, 0.546), 'bbox_mAP_75': (24.0, 0.624), 'bbox_mAP_50': (37.0, 0.894), 'LAMR': (38.0, 0.1575)}, {'bbox_mAP': (26.0, 0.547), 'bbox_mAP_75': (22.0, 0.613), 'bbox_mAP_50': (45.0, 0.876), 'LAMR': (27.0, 0.187)}, {'bbox_mAP': (6.0, 0.536), 'bbox_mAP_75': (6.0, 0.59), 'bbox_mAP_50': (6.0, 0.861), 'LAMR': (6.0, 0.1882)}, {'bbox_mAP': (15.0, 0.563), 'bbox_mAP_75': (15.0, 0.627), 'bbox_mAP_50': (30.0, 0.895), 'LAMR': (30.0, 0.1479)}]

# %% [markdown]
# Check the losses to see whether training with coupled λ is really smoother.

# %%
from log_analysis import *

sb.set_context('talk')
sb.set_style('whitegrid')
sb.set_palette(kit())
logs = [
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_fclayer_gTrue_seed_incr1.log',
    #     'GPA adversarial, λ 1:1 increasing'
    # ],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_fclayer_gTrue_seed_direct1.log',
    #     'fc → adversarial, λ 1:1 increasing, lr × 100'
    # ],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_fclayer_gTrue_seed_direct2.log',
    #     'fc → adversarial, λ 1:1 increasing'
    # ],
    [
        'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct5_adv.log',
        'pretraining'
    ],
    [
        'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct3.log',
        'adversarial, λ 1:1 increasing'
    ],
    [
        'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct10.log',
        'adversarial, λ 1:1 coupled'
    ],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct4.log',
    #     'adversarial, λ 1:1 increasing, lr × 10'
    # ],
    [
        'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct5.log',
        'adversarial, λ 1:1 increasing, pretrained'
    ],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct6.log',
    #     'adversarial, λ 1:1, pretrained'
    # ],
    [
        'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptiveAdversarial_1_1_1_1_none_gTrue_seed_direct7.log',
        'adversarial, λ 1:1 coupled, pretrained'
    ],
]

df, maxs = df_from_log(['setting'], ['roi_loss', 'rcnn_loss'], logs, get_max=True)

g = sb.relplot(data=df[df['occurrence'] <= 40],
               x='occurrence',
               y='value',
               kind='line',
               hue='setting',
               col='metric',
               height=5,
               aspect=1.)
g.set_axis_labels('epoch', 'AP@50')
g.set_titles(col_template='{col_name}', row_template='')
print(maxs)
# g.savefig(f'images/tuning_gpa_adversarial.svg')
# Out:
# [{'roi_loss': (1.0, 0.7077), 'rcnn_loss': (1.0, 0.7195)}, {'roi_loss': (31.0, 1.3573), 'rcnn_loss': (37.0, 1.1476)}, {'roi_loss': (73.0, 1.1865), 'rcnn_loss': (38.0, 0.8485)}, {'roi_loss': (23.0, 3.1239), 'rcnn_loss': (23.0, 2.7847)}, {'roi_loss': (23.0, 1.837), 'rcnn_loss': (21.0, 1.8924)}]

# %% [markdown]
# ## on backbone
# Test different modes to normalize size of input feature map. Sampling works best. Then check which features to deploy it on.

# %%
from log_analysis import *

sb.set_context('talk')
sb.set_style('whitegrid')
sb.set_palette(kit())
logs = [
    ['GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptive_0_0_0_0_fclayer_gTrue_seed_norot.log', 'fine-tune'],
    [
        'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptive_10_01_100_01_fclayer_gTrue_seed_norot.log',
        'GPA 10:0.1 | 100:0.1'
    ],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_seed_GPAtest.log', 'GPA 10:0.1 | 100:0.1 new'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_seed_GPAtest1.log', 'GPA 10:0.1 | 100:0.1 new'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_seed_GPAratio.log', "GPA 10:0.1 | 100:0.1 don't keep ratio"],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_seed_GPAratiotest.log', "GPA 10:0.1 | 100:0.1 don't keep ratio (also in test)"],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_seed_ADVneck4.log', 'ADV neck_4, coupled λ'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_sp.log', 'ADV neck_4, coupled λ, pretrained'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_p2_s.log', 'ADV neck_4 pool2, coupled λ'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_c_s.log', 'ADV neck_4 channel, coupled λ'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_ch_s.log', 'ADV neck_4 channel, coupled λ'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s_s.log', 'ADV neck_4 sample, coupled λ'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s16_s.log', 'ADV neck_4 sample 16, coupled λ'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck3_s16_s.log', 'ADV neck_3 sample 16, coupled λ'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck2_s16_s.log', 'ADV neck_2 sample 16, coupled λ'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck1_s16_s.log', 'ADV neck_1 sample 16, coupled λ'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16_s.log', 'ADV neck_0 sample 16, coupled λ'],
    ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneckall_s16_s.log', 'ADV neck all 16, 7²'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck024_s16_s.log', 'ADV neck 024 16, 7²'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneckall_02_s.log', 'ADV neck all 16, 19²-7², ×0.2'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck04_05_s.log', 'ADV neck 0|4 16, 19²-7², ×0.5'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck024_033_s.log', 'ADV neck 0|2|4 16, 19²-7², ×0.33'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVall_scdl_s.log', 'ADV all schedule'],
    ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVall_scdl_02_s.log', 'ADV all schedule ×0.2'],
    ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVall_scdl1_02_s.log', 'ADV all schedule 1'],
]

df, maxs = df_from_log(['setting'], ['bbox_mAP', 'bbox_mAP_75', 'bbox_mAP_50', 'LAMR'], logs, get_max=True)

g = sb.relplot(data=df[df['occurrence'] <= 80],
               x='occurrence',
               y='value',
               kind='line',
               hue='setting',
               col='metric',
               height=5,
               aspect=1.)
g.set_axis_labels('epoch', 'AP@50')
g.set_titles(col_template='{col_name}', row_template='')
print(maxs)
# g.savefig(f'images/tuning_gpa_adversarial.svg')
# Out:
# [{'bbox_mAP': (30.0, 0.566), 'bbox_mAP_75': (17.0, 0.632), 'bbox_mAP_50': (23.0, 0.874), 'LAMR': (24.0, 0.1594)}, {'bbox_mAP': (36.0, 0.576), 'bbox_mAP_75': (35.0, 0.648), 'bbox_mAP_50': (35.0, 0.902), 'LAMR': (36.0, 0.1378)}, {'bbox_mAP': (6.0, 0.552), 'bbox_mAP_75': (18.0, 0.637), 'bbox_mAP_50': (6.0, 0.86), 'LAMR': (6.0, 0.1909)}, {'bbox_mAP': (69.0, 0.57), 'bbox_mAP_75': (37.0, 0.64), 'bbox_mAP_50': (68.0, 0.877), 'LAMR': (68.0, 0.1572)}, {'bbox_mAP': (22.0, 0.586), 'bbox_mAP_75': (22.0, 0.665), 'bbox_mAP_50': (71.0, 0.896), 'LAMR': (71.0, 0.1442)}]

# %% [markdown]
# ## Effect of Sample Number and Size
# Test how number and size of sample (in relation to feature map size) affect performance.

# %%
from log_analysis import *

sb.set_context('talk')
sb.set_style('whitegrid')
sb.set_palette(kit())
logs = [
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptive_0_0_0_0_fclayer_gTrue_seed_norot.log', 'fine-tune'],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptive_10_01_100_01_fclayer_gTrue_seed_norot.log',
    #     'GPA 10:0.1 | 100:0.1'
    # ],
    # size on neck 4
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s16x9_s.log', 'ADV neck_4 sample 16, 9×9', 16, 9, 4],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s16_s.log', 'ADV neck_4 sample 16, 7×7', 16, 7, 4],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s16x5_s.log', 'ADV neck_4 sample 16, 5×5', 16, 5, 4],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s16x3_s.log', 'ADV neck_4 sample 16, 3×3', 16, 3, 4],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s16x1_s.log', 'ADV neck_4 sample 16, 1×1', 16, 1, 4],
    # size on neck 0
    ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x38_s.log', 'ADV neck_0 sample 16, 38×38', 16, 19, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x19_s.log', 'ADV neck_0 sample 16, 19×19', 16, 19, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x17_s.log', 'ADV neck_0 sample 16, 17×17', 16, 17, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x15_s.log', 'ADV neck_0 sample 16, 15×15', 16, 15, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x13_s.log', 'ADV neck_0 sample 16, 13×13', 16, 13, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x11_s.log', 'ADV neck_0 sample 16, 11×11', 16, 11, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x9_s.log', 'ADV neck_0 sample 16, 9×9', 16, 9, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x5_s.log', 'ADV neck_0 sample 16, 5×5', 16, 5, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x3_s.log', 'ADV neck_0 sample 16, 3×3', 16, 3, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x1_s.log', 'ADV neck_0 sample 16, 1×1', 16, 1, 0],
    # number on neck 4
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s20x7_s.log', 'ADV neck_4 7×7 sample 20', 20, 7, 4],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s30x7_s.log', 'ADV neck_4 7×7 sample 30', 30, 7, 4],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s50x7_s.log', 'ADV neck_4 7×7 sample 50', 50, 7, 4],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s100x7_s.log', 'ADV neck_4 7×7 sample 100', 100, 7, 4],
    # number on neck 0
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s20x3_s.log', 'ADV neck_0 3×3 sample 20', 20, 3, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s30x3_s.log', 'ADV neck_0 3×3 sample 30', 30, 3, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s50x3_s.log', 'ADV neck_0 3×3 sample 50', 50, 3, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s100x3_s.log', 'ADV neck_0 3×3 sample 100', 100, 3, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s20x7_s.log', 'ADV neck_0 7×7 sample 20', 20, 7, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s30x7_s.log', 'ADV neck_0 7×7 sample 30', 30, 7, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s50x7_s.log', 'ADV neck_0 7×7 sample 50', 50, 7, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s100x7_s.log', 'ADV neck_0 7×7 sample 100', 100, 7, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s20x13_s.log', 'ADV neck_0 13×13 sample 20', 20, 13, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s30x13_s.log', 'ADV neck_0 13×13 sample 30', 30, 13, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s50x13_s.log', 'ADV neck_0 13×13 sample 50', 50, 13, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s100x13_s.log', 'ADV neck_0 13×13 sample 100', 100, 13, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s20x19_s.log', 'ADV neck_0 19×19 sample 20', 20, 19, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s30x19_s.log', 'ADV neck_0 19×19 sample 30', 30, 19, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s50x19_s.log', 'ADV neck_0 19×19 sample 50', 50, 19, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s100x19_s.log', 'ADV neck_0 19×19 sample 100', 100, 19, 0],
]

df, maxs = df_from_log(['setting', 'number', 'size', 'neck'], ['bbox_mAP', 'bbox_mAP_75', 'bbox_mAP_50', 'LAMR'], logs, get_max=True)

g = sb.relplot(data=df[df['occurrence'] <= 40],
               x='occurrence',
               y='value',
               kind='line',
               hue='setting',
               col='metric',
               height=5,
               aspect=1.)
g.set_axis_labels('epoch', 'AP@50')
g.set_titles(col_template='{col_name}', row_template='')
print(maxs)
# g.savefig(f'images/tuning_gpa_adversarial.svg')
# Out:
# [{'bbox_mAP': (24.0, 0.577), 'bbox_mAP_75': (24.0, 0.654), 'bbox_mAP_50': (24.0, 0.885), 'LAMR': (24.0, 0.1605)}, {'bbox_mAP': (33.0, 0.583), 'bbox_mAP_75': (33.0, 0.674), 'bbox_mAP_50': (32.0, 0.9), 'LAMR': (33.0, 0.1491)}, {'bbox_mAP': (33.0, 0.582), 'bbox_mAP_75': (32.0, 0.659), 'bbox_mAP_50': (33.0, 0.897), 'LAMR': (33.0, 0.1442)}, {'bbox_mAP': (31.0, 0.584), 'bbox_mAP_75': (40.0, 0.676), 'bbox_mAP_50': (31.0, 0.9), 'LAMR': (38.0, 0.1374)}, {'bbox_mAP': (32.0, 0.575), 'bbox_mAP_75': (33.0, 0.652), 'bbox_mAP_50': (33.0, 0.882), 'LAMR': (31.0, 0.1605)}, {'bbox_mAP': (21.0, 0.596), 'bbox_mAP_75': (22.0, 0.675), 'bbox_mAP_50': (24.0, 0.912), 'LAMR': (24.0, 0.1239)}, {'bbox_mAP': (23.0, 0.597), 'bbox_mAP_75': (23.0, 0.683), 'bbox_mAP_50': (23.0, 0.917), 'LAMR': (24.0, 0.1175)}, {'bbox_mAP': (23.0, 0.597), 'bbox_mAP_75': (22.0, 0.678), 'bbox_mAP_50': (23.0, 0.912), 'LAMR': (23.0, 0.1261)}, {'bbox_mAP': (23.0, 0.594), 'bbox_mAP_75': (22.0, 0.667), 'bbox_mAP_50': (23.0, 0.908), 'LAMR': (
# ...

# %% [markdown]
# ## Adversarial with Ground-Truth Information
# Use ground-truths to sort samples in foreground/background categories.

# %%
from log_analysis import *

sb.set_context('talk')
sb.set_style('whitegrid')
sb.set_palette(kit())
logs = [
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptive_0_0_0_0_fclayer_gTrue_seed_norot.log', 'fine-tune'],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptive_10_01_100_01_fclayer_gTrue_seed_norot.log',
    #     'GPA 10:0.1 | 100:0.1'
    # ],
    # size on neck 4
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s16x9_s.log', 'ADV neck_4 sample 16, 9×9', 16, 9, 4],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s16_s.log', 'ADV neck_4 sample 16, 7×7', 16, 7, 4],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s16x5_s.log', 'ADV neck_4 sample 16, 5×5', 16, 5, 4],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s16x3_s.log', 'ADV neck_4 sample 16, 3×3', 16, 3, 4],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s16x1_s.log', 'ADV neck_4 sample 16, 1×1', 16, 1, 4],
    # size on neck 0
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x38_s.log', 'ADV neck_0 sample 16, 38×38', 16, 19, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x19_s.log', 'ADV neck_0 16, 19²'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x17_s.log', 'ADV neck_0 sample 16, 17×17', 16, 17, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x15_s.log', 'ADV neck_0 sample 16, 15×15', 16, 15, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x13_s.log', 'ADV neck_0 sample 16, 13×13', 16, 13, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x11_s.log', 'ADV neck_0 sample 16, 11×11', 16, 11, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x9_s.log', 'ADV neck_0 sample 16, 9×9', 16, 9, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x5_s.log', 'ADV neck_0 sample 16, 5×5', 16, 5, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x3_s.log', 'ADV neck_0 sample 16, 3×3', 16, 3, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s16x1_s.log', 'ADV neck_0 sample 16, 1×1', 16, 1, 0],
    # number on neck 4
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s20x7_s.log', 'ADV neck_4 7×7 sample 20', 20, 7, 4],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s30x7_s.log', 'ADV neck_4 7×7 sample 30', 30, 7, 4],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s50x7_s.log', 'ADV neck_4 7×7 sample 50', 50, 7, 4],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck4_s100x7_s.log', 'ADV neck_4 7×7 sample 100', 100, 7, 4],
    # number on neck 0
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s20x3_s.log', 'ADV neck_0 3×3 sample 20', 20, 3, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s30x3_s.log', 'ADV neck_0 3×3 sample 30', 30, 3, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s50x3_s.log', 'ADV neck_0 3×3 sample 50', 50, 3, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s100x3_s.log', 'ADV neck_0 3×3 sample 100', 100, 3, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s20x7_s.log', 'ADV neck_0 7×7 sample 20', 20, 7, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s30x7_s.log', 'ADV neck_0 7×7 sample 30', 30, 7, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s50x7_s.log', 'ADV neck_0 7×7 sample 50', 50, 7, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s100x7_s.log', 'ADV neck_0 7×7 sample 100', 100, 7, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s20x13_s.log', 'ADV neck_0 13×13 sample 20', 20, 13, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s30x13_s.log', 'ADV neck_0 13×13 sample 30', 30, 13, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s50x13_s.log', 'ADV neck_0 13×13 sample 50', 50, 13, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s100x13_s.log', 'ADV neck_0 13×13 sample 100', 100, 13, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s20x19_s.log', 'ADV neck_0 19×19 sample 20', 20, 19, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s30x19_s.log', 'ADV neck_0 30, 19²'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s50x19_s.log', 'ADV neck_0 19×19 sample 50', 50, 19, 0],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVneck0_s100x19_s.log', 'ADV neck_0 19×19 sample 100', 100, 19, 0],
    # GROUND-TRUTH
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVgtneck0_s.log', 'ADVgt neck_0 16|16, 19²'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVgtneck2_s.log', 'ADVgt neck_2 16|16, 13²'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVgtneck4_s.log', 'ADVgt neck_4 16|16, 7²'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVgtneck0_fg_s.log', 'ADVgt neck_0 16|0, 19²'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVgtneck2_fg_s.log', 'ADVgt neck_2 16|0, 13²'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVgtneck4_fg_s.log', 'ADVgt neck_4 16|0, 7²'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVgtneck0_d1_s.log', 'ADVgt neck_0 16|16, 19², .25 | .5'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVgtneck0_d2_s.log', 'ADVgt neck_0 16|16, 19², .25 | .75'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVgtneck0_d3_s.log', 'ADVgt neck_0 16|16, 19², .1 | .9'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVgtneck0_d4_s.log', 'ADVgt neck_0 16|16, 19², .05 | .95'],
    # COMBINATIONS
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADV012gt34_s.log', 'ADV 0,1,2 | gt 3,4'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADV34gt012_s.log', 'ADV 3,4 | gt 0,1,2'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVall_max_s.log', 'ADV all max'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADV0123_max_s.log', 'ADV 0123 max'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADV0124_max_s.log', 'ADV 0124 max'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADV0134_max_s.log', 'ADV 0134 max'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADV0234_max_s.log', 'ADV 0234 max'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADV1234_max_s.log', 'ADV 1234 max'],
    ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_cADV014_s.log', 'ADV 0,1,4'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_cADV01_s.log', 'ADV 0,1'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_cADV04_s.log', 'ADV 0,4'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_cADV14_s.log', 'ADV 1,4'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_cADV0_s.log', 'ADV 0'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_cADV1_s.log', 'ADV 1'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_cADV4_s.log', 'ADV 4'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_cADVgt0_s.log', 'ADV GT 0'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_dADVgt0_s.log', 'ADV GT 0 35²'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_cADVgt1_s.log', 'ADV GT 1'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_cADVgt4_s.log', 'ADV GT 4'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_cADVgt04_s.log', 'ADV GT 0,4'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_cADV0gt4_s.log', 'ADV 0 GT 4'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_cADV4gt0_s.log', 'ADV 4 GT 0'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADV014_cyc4_s.log', 'ADV 0,1,4 cycle 4'],
    ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVbb0_s.log', 'ADV backbone 0'],
    ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVbb1_s.log', 'ADV backbone 1'],
    ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVbb3_s.log', 'ADV backbone 3'],
    ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVbb0123_s.log', 'ADV backbone 0,1,2,3'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_eADVgt014_s.log', 'ADV GT 0,1,4'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_eADVgt01_s.log', 'ADV GT 0,1'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_eADVgt04_s.log', 'ADV GT 0,4'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_eADVgt14_s.log', 'ADV GT 1,4'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_eADVgt0_s.log', 'ADV GT 0'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_eADVgt1_s.log', 'ADV GT 1'],
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_eADVgt4_s.log', 'ADV GT 4'],

]

df, maxs = df_from_log(['setting'], ['bbox_mAP', 'bbox_mAP_75', 'bbox_mAP_50', 'LAMR'],
                       logs,
                       get_max=True)

g = sb.relplot(data=df[df['occurrence'] <= 40],
               x='occurrence',
               y='value',
               kind='line',
               hue='setting',
               col='metric',
               height=5,
               aspect=1.)
g.set_axis_labels('epoch', 'AP@50')
g.set_titles(col_template='{col_name}', row_template='')
print(maxs)
# g.savefig(f'images/tuning_gpa_adversarial.svg')
# Out:
# [{'bbox_mAP': (22.0, 0.598), 'bbox_mAP_75': (22.0, 0.692), 'bbox_mAP_50': (23.0, 0.902), 'LAMR': (23.0, 0.1397)}, {'bbox_mAP': (32.0, 0.565), 'bbox_mAP_75': (33.0, 0.632), 'bbox_mAP_50': (37.0, 0.87), 'LAMR': (24.0, 0.1721)}, {'bbox_mAP': (36.0, 0.567), 'bbox_mAP_75': (37.0, 0.637), 'bbox_mAP_50': (28.0, 0.875), 'LAMR': (24.0, 0.1666)}, {'bbox_mAP': (29.0, 0.571), 'bbox_mAP_75': (30.0, 0.64), 'bbox_mAP_50': (27.0, 0.874), 'LAMR': (27.0, 0.1608)}, {'bbox_mAP': (33.0, 0.565), 'bbox_mAP_75': (32.0, 0.632), 'bbox_mAP_50': (36.0, 0.869), 'LAMR': (25.0, 0.1701)}]

# %% [markdown]
# ## Adversarial + GPA

# %%
from log_analysis import *

sb.set_context('talk')
sb.set_style('whitegrid')
sb.set_palette(kit())
logs = [
    # ['GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptive_0_0_0_0_fclayer_gTrue_seed_norot.log', 'fine-tune'],
    # [
    #     'GPA/tuning/coco_piropo_20a_TwoStageDetectorAdaptive_10_01_100_01_fclayer_gTrue_seed_norot.log',
    #     'GPA 10:0.1 | 100:0.1'
    # ],
    ['GPA/tuning/coco_piropo_20a_TwoStageDetectorDA_ADVallGPA-xg_s.log', 'ADV all GPA - | gt+ | gt'],
]

df, maxs = df_from_log(['setting'], ['bbox_mAP', 'bbox_mAP_75', 'bbox_mAP_50', 'LAMR'], logs, get_max=True)

g = sb.relplot(data=df[df['occurrence'] <= 40],
               x='occurrence',
               y='value',
               kind='line',
               hue='setting',
               col='metric',
               height=5,
               aspect=1.)
g.set_axis_labels('epoch', 'AP@50')
g.set_titles(col_template='{col_name}', row_template='')
print(maxs)
# g.savefig(f'images/tuning_gpa_adversarial.svg')
# Out:
# [{'bbox_mAP': (36.0, 0.585), 'bbox_mAP_75': (35.0, 0.683), 'bbox_mAP_50': (37.0, 0.892), 'LAMR': (36.0, 0.1524)}]
